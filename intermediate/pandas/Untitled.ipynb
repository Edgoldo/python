# %%
import pandas as pd
registers = pd.read_csv("acrftreg.csv")
registers.head()
# Out:
#   Mark                           Manu  Type      Model    Serial    MTOW  \
# 0  AAA  DE HAVILLAND AIRCRAFT COMPANY   NaN      DH-83      DHA6   907.0
# 1  AAB   BRITISH AIRCRAFT CORPORATION   NaN  SWALLOW 2       461   680.0
# 2  AAD           PILATUS AIRCRAFT LTD   NaN  PC-12/47E      1068  4740.0
# 3  AAE            AUSTER AIRCRAFT LTD   NaN        J1B      2680   907.0
# 4  AAF        CESSNA AIRCRAFT COMPANY   NaN       182Q  18265648  1338.0
#
#    engnum                          Engmanu    Engtype              Engmodel  \
# 0       1  DE HAVILLAND ENGINE COMPANY LTD     Piston  GIPSY MAJOR(DE HAVL)
# 1       1                BLACKBURN ENGINES     Piston        CIRRUS MINOR I
# 2       1           PRATT & WHITNEY CANADA  Turboprop              PT6A-67P
# 3       1  DE HAVILLAND ENGINE COMPANY LTD     Piston  GIPSY MAJOR(DE HAVL)
# 4       1      TELEDYNE-CONTINENTAL MOTORS     Piston                 O-470
#
# ...

# %%
reg_result = registers.query("engnum > 1 and not Countrymanu == 'Australia'")
reg_result.head()
reg_result.shape
# Out:
# (2618, 45)
